# %%
from pathlib import Path

import pandas as pd

# %%
p = Path("data/c10_wx.csv")
wx = pd.read_csv(p, skiprows=3, header=None, names=['datetime', 'temp', 'dewpt_temp', 'rh', 'wind_chill', 'wind_dir', 'wind_spd'])

wx['datetime'] = pd.to_datetime(wx['datetime'], format='%b %d, %I:%M %p') + pd.DateOffset(years=123)

wx
# Out:
#                datetime  temp  dewpt_temp   rh  wind_chill wind_dir  wind_spd
# 0   2023-07-23 15:00:00     5           5  100         1.0      ESE        21
# 1   2023-07-23 14:00:00     5           5  100         1.0      ESE        21
# 2   2023-07-23 13:00:00     5           5  100         1.0      ESE        22
# 3   2023-07-23 12:00:00     6           6  100         2.0      ESE        22
# 4   2023-07-23 11:00:00     6           6  100         1.0      ESE        24
# ..                  ...   ...         ...  ...         ...      ...       ...
# 525 2023-06-30 20:00:00     3           3  100         NaN        E         1
# 526 2023-06-30 19:00:00     3           3   97         NaN        E         2
# 527 2023-06-30 18:00:00     3           2   95         NaN        E         3
# 528 2023-06-30 17:00:00     2           2   98         NaN      ESE         8
# 529 2023-06-30 16:00:00     2           2  100         0.0       SE        10
#
# [530 rows x 7 columns]

# %%
print(wx.datetime.head(50))
# Out:
# 0    2023-07-23 15:00:00
# 1    2023-07-23 14:00:00
# 2    2023-07-23 13:00:00
# 3    2023-07-23 12:00:00
# 4    2023-07-23 11:00:00
# 5    2023-07-23 10:00:00
# 6    2023-07-23 09:00:00
# 7    2023-07-23 08:00:00
# 8    2023-07-23 07:00:00
# 9    2023-07-23 06:00:00
# 10   2023-07-23 05:00:00
# 11   2023-07-23 04:00:00
# 12   2023-07-23 03:00:00
# 13   2023-07-23 02:00:00
# 14   2023-07-23 01:00:00
# 15   2023-07-23 00:00:00
# 16   2023-07-22 23:00:00
# 17   2023-07-22 22:00:00
# 18   2023-07-22 21:00:00
# 19   2023-07-22 20:00:00
# 20   2023-07-22 19:00:00
# 21   2023-07-22 18:00:00
# 22   2023-07-22 17:00:00
# 23   2023-07-22 16:00:00
# 24   2023-07-22 15:00:00
# 25   2023-07-22 14:00:00
# 26   2023-07-22 13:00:00
# 27   2023-07-22 12:00:00
# 28   2023-07-22 11:00:00
# 29   2023-07-22 10:00:00
# 30   2023-07-22 09:00:00
# 31   2023-07-22 08:00:00
# 32   2023-07-22 07:00:00
# 33   2023-07-22 06:00:00
# 34   2023-07-22 05:00:00
# 35   2023-07-22 04:00:00
# 36   2023-07-22 03:00:00
# ...
